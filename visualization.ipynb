# %%
from scripts import NOAADataDownloader
from utils import heplers

# %%
import pandas as pd 
import numpy as np
import matplotlib as plt

# %%
data =  "./data/data.csv"

# %%
df = pd.read_csv(data)

# %%
df
# Out:
#          month   AverageMonthTemperature
# 0   1949-01-01                        13
# 1   1949-02-01                        14
# 2   1949-03-01                        16
# 3   1949-04-01                        20
# 4   1949-05-01                        21
# ..         ...                       ...
# 94  1960-11-01                        17
# 95  1960-12-01                        12
# 96  1961-01-01                         8
# 97  1961-02-01                        14
# 98  1961-03-01                        16
#
# [99 rows x 2 columns]

# %%
m  = df[" AverageMonthTemperature"].astype(float)
m
# Out:
# 0     13.0
# 1     14.0
# 2     16.0
# 3     20.0
# 4     21.0
#       ...
# 94    17.0
# 95    12.0
# 96     8.0
# 97    14.0
# 98    16.0
# Name:  AverageMonthTemperature, Length: 99, dtype: float64

# %%
import matplotlib.pyplot   as plt



# Plotting the df
plt.figure(figsize=(12, 6))
plt.plot(df['month'], df[" AverageMonthTemperature"].astype(float), label="Average Monthly Temperature", color='blue')

# Labeling the axes andftle
plt.xlabel('df')
plt.ylabel('Average Temperature (°C)')
plt.title('Average Monthly Temperature Over Time')
# dflay the plot
plt.show()

# %%
new_data = pd.read_csv("./data/result_yearFes.csv")

# %%
new_data
# Out:
#    Year    AverageYearTemperature
# 0   1949                       23
# 1   1950                       31
# 2   1951                       20
# 3   1952                       21
# 4   1957                       17
# 5   1958                       20
# 6   1959                       17
# 7   1960                       19
# 8   1961                       14

# %%
plt.figure(figsize=(12, 6))
plt.plot(new_data['Year'], new_data["AverageMonthTemperature"].astype(float), label="Average Monthly Temperature", color='blue')

# Labeling the axes andftle
plt.xlabel('df')
plt.ylabel('Average Temperature (°C)')
plt.title('Average Monthly Temperature Over Time')
# dflay the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# ...
